# %%
import folium

seoul_map = folium.Map(location=[37.5614378, 126.9751701], zoom_start=14) # 위도와 경도

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([37.5614378, 126.9751701], popup='서울시청').add_to(seoul_map)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

school_path = r'/Users/gamgoon/Development/ML/realty/2019년_공시대상학교정보(전체).xlsx'
school_raw = pd.read_excel(school_path)
school_data = school_raw[['정보공시 \n 학교코드', '학교명', '위도', '경도']]
school_data.columns = ['학교코드', '학교명', '위도', '경도']
school_df = school_data.drop_duplicates()

# %%
school_df
# Out:
#              학교코드                 학교명         위도          경도
# 0      S000003511       서울교육대학교부설초등학교  37.490739  127.015424
# 1      S000003563     서울대학교사범대학부설초등학교  37.577017  127.003091
# 2      S010000738            서울개일초등학교  37.486214  127.057742
# 3      S010000741            서울구룡초등학교  37.481193  127.051755
# 4      S010000742            서울논현초등학교  37.500000  127.000000
# 5      S010000743            서울대곡초등학교  37.494712  127.065026
# 6      S010000744            서울대도초등학교  37.492768  127.053346
# 7      S010000745            서울대모초등학교  37.481536  127.086562
# 8      S010000746            서울대왕초등학교  37.464621  127.105589
# 9      S010000747            서울대진초등학교  37.497011  127.078078
# 10     S010000748            서울대청초등학교  37.493133  127.087786
# 11     S010000749            서울대치초등학교  37.491311  127.061966
# 12     S010000750            서울대현초등학교  37.500000  127.100000
# 13     S010000751            서울도곡초등학교  37.499507  127.054446
# 14     S010000752            서울도성초등학교  37.501463  127.048874
# 15     S010000753            서울반원초등학교  37.500000  127.000000
# 16     S010000754            서울반포초등학교  37.502886  126.991500
# 17     S010000755            서울방배초등학교  37.486764  126.987137
# 18     S010000756            서울방일초등학교  37.400000  126.900000
# 19     S010000757            서울방현초등학교  37.400000  126.900000
# 20     S010000758            서울봉은초등학교  37.520083  127.060931
# 21     S010000759            서울삼릉초등학교  37.513260  127.046950
# 22     S010000760            서울서래초등학교  37.500000  126.900000
# 23     S010000761            서울서원초등학교  37.500000  127.000000
# 24     S010000762            서울서이초등학교  37.500000  127.000000
# 25     S010000763            서울서일초등학교  37.485296  127.022161
# 26     S010000764            서울서초초등학교  37.499311  127.024064
# 27     S010000765            서울수서초등학교  37.400000  127.100000
# 28     S010000766            서울신구초등학교  37.523361  127.023992
# 29     S010000767            서울신동초등학교  37.517128  127.011388
# ...           ...                 ...        ...         ...
# 12144  S170000126              세화고등학교  33.516242  126.862754
# 12145  S170000127            제주제일고등학교  33.480030  126.479518
# 12146  S170000128          제주중앙여자고등학교  33.490935  126.539488
# 12147  S170000129              한림고등학교  33.398124  126.258225
# 12148  S170000130              남녕고등학교  33.489942  126.482604
# 12149  S170000131              남주고등학교  33.275937  126.564457
# 12150  S170000132              대기고등학교  33.493718  126.592600
# 12151  S170000134            삼성여자고등학교  33.255042  126.584178
# 12152  S170000135            신성여자고등학교  33.400000  126.500000
# 12153  S170000136              오현고등학교  33.500000  126.500000
# 12154  S170000137            제주여자고등학교  33.482060  126.540963
# 12155  S170000140              애월고등학교  33.460221  126.333398
# 12156  S170000143          제주여자상업고등학교  33.515067  126.536312
# 12157  S170000144              중문고등학교  33.254748  126.447560
# 12158  S170000146              표선고등학교  33.331175  126.827913
# 12159  S170000148            한림공업고등학교  33.407607  126.268975
# 12160  S170000150              함덕고등학교  33.544583  126.651912
# 12161  S170000152            한국뷰티고등학교  33.300370  126.181345
# 12162  S170000153              영주고등학교  33.455086  126.579755
# 12163  S170000154            제주중앙고등학교  33.474585  126.572462
# 12164  S170000156            제주과학고등학교  33.426620  126.531445
# 12165  S170000157              제주고등학교  33.472418  126.481988
# 12166  S170000158         서귀포산업과학고등학교  33.297142  126.594400
# 12167  S170000159              성산고등학교  33.469821  126.915403
# 12168  S170000773           제주외국어고등학교  33.433989  126.425809
# 12169  S170000512              제주영지학교  33.488117  126.542748
# 12170  S170000513              제주영송학교  33.450047  126.434217
# 12171  S170000790             서귀포온성학교  33.291338  126.593310
# 12172  S170000155  제주제일고등학교부설방송통신고등학교  33.480030  126.479518
# 12173  S170000870    제주제일중학교부설방송통신중학교  33.495201  126.538850
#
# [12174 rows x 4 columns]

# %%
def graduate_preprocessing(path):
    raw_graduate = pd.read_excel(path, sheet_name='2018_졸업생의 진로 현황(중)')
    select_col = raw_graduate[['지역', '학교명', '정보공시 \n 학교코드', '졸업자.2', '(특수목적고)과학고 진학자.2', '(특수목적고)외고ㆍ국제고 진학자.2']]
    select_col.columns = ['지역', '학교명', '학교코드', '졸업자', '과고', '외고']
    graduate_data = select_col.drop(0)
    graduate_data['과고'] = pd.to_numeric(graduate_data['과고'])
    graduate_data['외고'] = pd.to_numeric(graduate_data['외고'])
    graduate_data['졸업자'] = pd.to_numeric(graduate_data['졸업자'])
    graduate_data['총합'] = graduate_data['과고'] + graduate_data['외고']
    
    def get_sido(x):
        temp = x.split(' ')[0]
        if len(temp) != 4:
            return temp[:2]
        else:
            return temp[0] + temp[2]
    
    graduate_data['시도'] = graduate_data['지역'].dropna().apply(get_sido)
    graduate_data['구군'] = graduate_data['지역'].dropna().apply(lambda x: x.split(' ')[1])
    
    graduate_data.at[3011, '시도'] = '경북'
    graduate_data.at[3011, '구군'] = '예천군'
    
    return graduate_data

graduate_path = r'/Users/gamgoon/Development/ML/realty/진로_2018.xlsx'
graduate_df = graduate_preprocessing(graduate_path)

# %%
graduate_df
# Out:
#                 지역               학교명        학교코드    졸업자    과고    외고    총합  시도  \
# 1        서울특별시 성북구    서울대학교사범대학부설중학교  S000003514  234.0   4.0   5.0   9.0  서울
# 2        서울특별시 종로구  서울대학교사범대학부설여자중학교  S000003562  172.0   0.0   8.0   8.0  서울
# 3        서울특별시 강남구             개원중학교  S010000698  214.0   2.0   9.0  11.0  서울
# 4        서울특별시 서초구             경원중학교  S010000700  310.0   5.0   4.0   9.0  서울
# 5        서울특별시 강남구             구룡중학교  S010000701  256.0   3.0   4.0   7.0  서울
# 6        서울특별시 강남구            압구정중학교  S010000702  116.0   2.0   5.0   7.0  서울
# 7        서울특별시 강남구    단국대학교사범대학부속중학교  S010000704  191.0   3.0   4.0   7.0  서울
# 8        서울특별시 강남구             대명중학교  S010000705  305.0   2.0   7.0   9.0  서울
# 9        서울특별시 강남구             대왕중학교  S010000706  275.0   6.0   8.0  14.0  서울
# 10       서울특별시 강남구             대청중학교  S010000707  336.0  12.0  10.0  22.0  서울
# 11       서울특별시 강남구             대치중학교  S010000708  157.0   4.0   2.0   6.0  서울
# 12       서울특별시 강남구             도곡중학교  S010000709  229.0  11.0  12.0  23.0  서울
# 13       서울특별시 서초구           동덕여자중학교  S010000710  149.0   0.0   3.0   3.0  서울
# 14       서울특별시 서초구             반포중학교  S010000711  300.0   3.0   3.0   6.0  서울
# 15       서울특별시 서초구             방배중학교  S010000712  165.0   2.0   5.0   7.0  서울
# 16       서울특별시 강남구             봉은중학교  S010000713  153.0   0.0   2.0   2.0  서울
# 17       서울특별시 서초구           서문여자중학교  S010000714  247.0   0.0   1.0   1.0  서울
# 18       서울특별시 서초구             서운중학교  S010000715  286.0   3.0   9.0  12.0  서울
# 19       서울특별시 서초구             서일중학교  S010000716  302.0   9.0  13.0  22.0  서울
# 20       서울특별시 서초구             서초중학교  S010000717  229.0   8.0   2.0  10.0  서울
# 21       서울특별시 서초구           세화여자중학교  S010000718  287.0   0.0   8.0   8.0  서울
# 22       서울특별시 강남구             수서중학교  S010000719  155.0   1.0   1.0   2.0  서울
# 23       서울특별시 강남구           숙명여자중학교  S010000720  303.0   2.0  11.0  13.0  서울
# 24       서울특별시 강남구             신구중학교  S010000721  124.0   0.0   6.0   6.0  서울
# 25       서울특별시 서초구             신동중학교  S010000722  256.0  14.0   7.0  21.0  서울
# 26       서울특별시 서초구            신반포중학교  S010000723  263.0   3.0   3.0   6.0  서울
# 27       서울특별시 강남구             신사중학교  S010000724  154.0   2.0   5.0   7.0  서울
# 28       서울특별시 서초구             언남중학교  S010000725  191.0   0.0   0.0   0.0  서울
# 29       서울특별시 강남구             언북중학교  S010000726  128.0   0.0   1.0   1.0  서울
# 30       서울특별시 강남구             언주중학교  S010000727  307.0   6.0   9.0  15.0  서울
# ...            ...               ...         ...    ...   ...   ...   ...  ..
# 3429  제주특별자치도 서귀포시          서귀포대신중학교  S170000281  152.0   0.0   2.0   2.0  제주
# 3430  제주특별자치도 서귀포시             성산중학교  S170000282   72.0   0.0   3.0   3.0  제주
# 3431  제주특별자치도 서귀포시             신산중학교  S170000283   13.0   0.0   0.0   0.0  제주
# 3432  제주특별자치도 서귀포시             안덕중학교  S170000284   70.0   0.0   0.0   0.0  제주
# 3433  제주특별자치도 서귀포시             위미중학교  S170000285   34.0   0.0   2.0   2.0  제주
# 3434  제주특별자치도 서귀포시             중문중학교  S170000286  143.0   1.0   3.0   4.0  제주
# 3435  제주특별자치도 서귀포시             표선중학교  S170000287   63.0   0.0   1.0   1.0  제주
# 3436  제주특별자치도 서귀포시             효돈중학교  S170000288   59.0   0.0   2.0   2.0  제주
# 3437  제주특별자치도 서귀포시             남주중학교  S170000289  129.0   1.0   0.0   1.0  제주
# 3438  제주특별자치도 서귀포시          서귀포여자중학교  S170000290  150.0   0.0   0.0   0.0  제주
# 3439  제주특별자치도 서귀포시            서귀포중학교  S170000291  227.0   1.0   7.0   8.0  제주
# 3440   제주특별자치도 제주시          제주동여자중학교  S170000426  252.0   0.0   6.0   6.0  제주
# 3441   제주특별자치도 제주시            제주동중학교  S170000427  182.0   0.0   3.0   3.0  제주
# 3442   제주특별자치도 제주시            제주서중학교  S170000428  299.0   0.0   4.0   4.0  제주
# 3443   제주특별자치도 제주시             아라중학교  S170000429  251.0   3.0   5.0   8.0  제주
# 3444   제주특별자치도 제주시           제주제일중학교  S170000430  320.0   3.0   5.0   8.0  제주
# 3445   제주특별자치도 제주시         제주중앙여자중학교  S170000431  183.0   1.0   3.0   4.0  제주
# 3446   제주특별자치도 제주시           제주중앙중학교  S170000432  384.0   6.0   2.0   8.0  제주
# 3447   제주특별자치도 제주시           신성여자중학교  S170000433  245.0   0.0   3.0   3.0  제주
# 3448   제주특별자치도 제주시             오현중학교  S170000434  229.0   4.0   5.0   9.0  제주
# 3449   제주특별자치도 제주시           제주여자중학교  S170000435  258.0   0.0   3.0   3.0  제주
# 3450   제주특별자치도 제주시             제주중학교  S170000436  203.0   1.0   0.0   1.0  제주
# 3451   제주특별자치도 제주시             한라중학교  S170000438  374.0   7.0   3.0  10.0  제주
# 3452   제주특별자치도 제주시             노형중학교  S170000835  388.0   0.0  11.0  11.0  제주
# 3453   제주특별자치도 제주시             오름중학교  S170000838  193.0   0.0   5.0   5.0  제주
# 3454   제주특별자치도 제주시             탐라중학교  S170000844  298.0   1.0   1.0   2.0  제주
# 3455   제주특별자치도 제주시            제주영지학교  S170000512   12.0   0.0   0.0   0.0  제주
# 3456   제주특별자치도 제주시            제주영송학교  S170000513   21.0   0.0   0.0   0.0  제주
# 3457  제주특별자치도 서귀포시           서귀포온성학교  S170000790    9.0   0.0   0.0   0.0  제주
# 3458   제주특별자치도 제주시  제주제일중학교부설방송통신중학교  S170000870    NaN   NaN   NaN   NaN  제주
#
#         구군
# 1      성북구
# 2      종로구
# 3      강남구
# 4      서초구
# 5      강남구
# 6      강남구
# 7      강남구
# 8      강남구
# 9      강남구
# 10     강남구
# 11     강남구
# 12     강남구
# 13     서초구
# 14     서초구
# 15     서초구
# 16     강남구
# 17     서초구
# 18     서초구
# 19     서초구
# 20     서초구
# 21     서초구
# 22     강남구
# 23     강남구
# 24     강남구
# 25     서초구
# 26     서초구
# 27     강남구
# 28     서초구
# 29     강남구
# 30     강남구
# ...    ...
# 3429  서귀포시
# 3430  서귀포시
# 3431  서귀포시
# 3432  서귀포시
# 3433  서귀포시
# 3434  서귀포시
# 3435  서귀포시
# 3436  서귀포시
# 3437  서귀포시
# 3438  서귀포시
# 3439  서귀포시
# 3440   제주시
# 3441   제주시
# 3442   제주시
# 3443   제주시
# 3444   제주시
# 3445   제주시
# 3446   제주시
# 3447   제주시
# 3448   제주시
# 3449   제주시
# 3450   제주시
# 3451   제주시
# 3452   제주시
# 3453   제주시
# 3454   제주시
# 3455   제주시
# 3456   제주시
# 3457  서귀포시
# 3458   제주시
#
# [3458 rows x 9 columns]

# %%
# 각 중학교의 상세 정보와 특목고 진학에 관한 데이터프레임을 하나로 합치기
total_school_df = pd.merge(graduate_df, school_df, how='inner', right_on='학교코드', left_on='학교코드')

# %%
total_school_df
# Out:
#                 지역             학교명_x        학교코드    졸업자    과고    외고    총합  시도  \
# 0        서울특별시 성북구    서울대학교사범대학부설중학교  S000003514  234.0   4.0   5.0   9.0  서울
# 1        서울특별시 종로구  서울대학교사범대학부설여자중학교  S000003562  172.0   0.0   8.0   8.0  서울
# 2        서울특별시 강남구             개원중학교  S010000698  214.0   2.0   9.0  11.0  서울
# 3        서울특별시 서초구             경원중학교  S010000700  310.0   5.0   4.0   9.0  서울
# 4        서울특별시 강남구             구룡중학교  S010000701  256.0   3.0   4.0   7.0  서울
# 5        서울특별시 강남구            압구정중학교  S010000702  116.0   2.0   5.0   7.0  서울
# 6        서울특별시 강남구    단국대학교사범대학부속중학교  S010000704  191.0   3.0   4.0   7.0  서울
# 7        서울특별시 강남구             대명중학교  S010000705  305.0   2.0   7.0   9.0  서울
# 8        서울특별시 강남구             대왕중학교  S010000706  275.0   6.0   8.0  14.0  서울
# 9        서울특별시 강남구             대청중학교  S010000707  336.0  12.0  10.0  22.0  서울
# 10       서울특별시 강남구             대치중학교  S010000708  157.0   4.0   2.0   6.0  서울
# 11       서울특별시 강남구             도곡중학교  S010000709  229.0  11.0  12.0  23.0  서울
# 12       서울특별시 서초구           동덕여자중학교  S010000710  149.0   0.0   3.0   3.0  서울
# 13       서울특별시 서초구             반포중학교  S010000711  300.0   3.0   3.0   6.0  서울
# 14       서울특별시 서초구             방배중학교  S010000712  165.0   2.0   5.0   7.0  서울
# 15       서울특별시 강남구             봉은중학교  S010000713  153.0   0.0   2.0   2.0  서울
# 16       서울특별시 서초구           서문여자중학교  S010000714  247.0   0.0   1.0   1.0  서울
# 17       서울특별시 서초구             서운중학교  S010000715  286.0   3.0   9.0  12.0  서울
# 18       서울특별시 서초구             서일중학교  S010000716  302.0   9.0  13.0  22.0  서울
# 19       서울특별시 서초구             서초중학교  S010000717  229.0   8.0   2.0  10.0  서울
# 20       서울특별시 서초구           세화여자중학교  S010000718  287.0   0.0   8.0   8.0  서울
# 21       서울특별시 강남구             수서중학교  S010000719  155.0   1.0   1.0   2.0  서울
# 22       서울특별시 강남구           숙명여자중학교  S010000720  303.0   2.0  11.0  13.0  서울
# 23       서울특별시 강남구             신구중학교  S010000721  124.0   0.0   6.0   6.0  서울
# 24       서울특별시 서초구             신동중학교  S010000722  256.0  14.0   7.0  21.0  서울
# 25       서울특별시 서초구            신반포중학교  S010000723  263.0   3.0   3.0   6.0  서울
# 26       서울특별시 강남구             신사중학교  S010000724  154.0   2.0   5.0   7.0  서울
# 27       서울특별시 서초구             언남중학교  S010000725  191.0   0.0   0.0   0.0  서울
# 28       서울특별시 강남구             언북중학교  S010000726  128.0   0.0   1.0   1.0  서울
# 29       서울특별시 강남구             언주중학교  S010000727  307.0   6.0   9.0  15.0  서울
# ...            ...               ...         ...    ...   ...   ...   ...  ..
# 3413  제주특별자치도 서귀포시          서귀포대신중학교  S170000281  152.0   0.0   2.0   2.0  제주
# 3414  제주특별자치도 서귀포시             성산중학교  S170000282   72.0   0.0   3.0   3.0  제주
# 3415  제주특별자치도 서귀포시             신산중학교  S170000283   13.0   0.0   0.0   0.0  제주
# 3416  제주특별자치도 서귀포시             안덕중학교  S170000284   70.0   0.0   0.0   0.0  제주
# 3417  제주특별자치도 서귀포시             위미중학교  S170000285   34.0   0.0   2.0   2.0  제주
# 3418  제주특별자치도 서귀포시             중문중학교  S170000286  143.0   1.0   3.0   4.0  제주
# 3419  제주특별자치도 서귀포시             표선중학교  S170000287   63.0   0.0   1.0   1.0  제주
# 3420  제주특별자치도 서귀포시             효돈중학교  S170000288   59.0   0.0   2.0   2.0  제주
# 3421  제주특별자치도 서귀포시             남주중학교  S170000289  129.0   1.0   0.0   1.0  제주
# 3422  제주특별자치도 서귀포시          서귀포여자중학교  S170000290  150.0   0.0   0.0   0.0  제주
# 3423  제주특별자치도 서귀포시            서귀포중학교  S170000291  227.0   1.0   7.0   8.0  제주
# 3424   제주특별자치도 제주시          제주동여자중학교  S170000426  252.0   0.0   6.0   6.0  제주
# 3425   제주특별자치도 제주시            제주동중학교  S170000427  182.0   0.0   3.0   3.0  제주
# 3426   제주특별자치도 제주시            제주서중학교  S170000428  299.0   0.0   4.0   4.0  제주
# 3427   제주특별자치도 제주시             아라중학교  S170000429  251.0   3.0   5.0   8.0  제주
# 3428   제주특별자치도 제주시           제주제일중학교  S170000430  320.0   3.0   5.0   8.0  제주
# 3429   제주특별자치도 제주시         제주중앙여자중학교  S170000431  183.0   1.0   3.0   4.0  제주
# 3430   제주특별자치도 제주시           제주중앙중학교  S170000432  384.0   6.0   2.0   8.0  제주
# 3431   제주특별자치도 제주시           신성여자중학교  S170000433  245.0   0.0   3.0   3.0  제주
# 3432   제주특별자치도 제주시             오현중학교  S170000434  229.0   4.0   5.0   9.0  제주
# 3433   제주특별자치도 제주시           제주여자중학교  S170000435  258.0   0.0   3.0   3.0  제주
# 3434   제주특별자치도 제주시             제주중학교  S170000436  203.0   1.0   0.0   1.0  제주
# 3435   제주특별자치도 제주시             한라중학교  S170000438  374.0   7.0   3.0  10.0  제주
# 3436   제주특별자치도 제주시             노형중학교  S170000835  388.0   0.0  11.0  11.0  제주
# 3437   제주특별자치도 제주시             오름중학교  S170000838  193.0   0.0   5.0   5.0  제주
# 3438   제주특별자치도 제주시             탐라중학교  S170000844  298.0   1.0   1.0   2.0  제주
# 3439   제주특별자치도 제주시            제주영지학교  S170000512   12.0   0.0   0.0   0.0  제주
# 3440   제주특별자치도 제주시            제주영송학교  S170000513   21.0   0.0   0.0   0.0  제주
# 3441  제주특별자치도 서귀포시           서귀포온성학교  S170000790    9.0   0.0   0.0   0.0  제주
# 3442   제주특별자치도 제주시  제주제일중학교부설방송통신중학교  S170000870    NaN   NaN   NaN   NaN  제주
#
#         구군             학교명_y         위도          경도
# 0      성북구    서울대학교사범대학부설중학교  37.596201  127.039164
# 1      종로구  서울대학교사범대학부설여자중학교  37.577928  127.003899
# 2      강남구             개원중학교  37.491641  127.071415
# 3      서초구             경원중학교  37.510997  127.008879
# 4      강남구             구룡중학교  37.486153  127.056123
# 5      강남구            압구정중학교  37.530239  127.032986
# 6      강남구    단국대학교사범대학부속중학교  37.400000  127.000000
# 7      강남구             대명중학교  37.506056  127.061064
# 8      강남구             대왕중학교  37.483457  127.087340
# 9      강남구             대청중학교  37.490430  127.058351
# 10     강남구             대치중학교  37.400000  127.000000
# 11     강남구             도곡중학교  37.492306  127.045218
# 12     서초구           동덕여자중학교  37.400000  126.900000
# 13     서초구             반포중학교  37.500000  126.900000
# 14     서초구             방배중학교  37.494454  126.998434
# 15     강남구             봉은중학교  37.500000  127.000000
# 16     서초구           서문여자중학교  37.488770  126.984628
# 17     서초구             서운중학교  37.400000  127.000000
# 18     서초구             서일중학교  37.498530  127.023219
# 19     서초구             서초중학교  37.485539  127.008521
# 20     서초구           세화여자중학교  37.500000  126.900000
# 21     강남구             수서중학교  37.491204  127.102379
# 22     강남구           숙명여자중학교  37.491474  127.052612
# 23     강남구             신구중학교  37.527283  127.032160
# 24     서초구             신동중학교  37.516699  127.013192
# 25     서초구            신반포중학교  37.505955  126.995829
# 26     강남구             신사중학교  37.524699  127.021191
# 27     서초구             언남중학교  37.400000  127.000000
# 28     강남구             언북중학교  37.519427  127.033126
# 29     강남구             언주중학교  37.500000  127.000000
# ...    ...               ...        ...         ...
# 3413  서귀포시          서귀포대신중학교  33.257137  126.506607
# 3414  서귀포시             성산중학교  33.443613  126.910650
# 3415  서귀포시             신산중학교  33.380909  126.875348
# 3416  서귀포시             안덕중학교  33.249009  126.337491
# 3417  서귀포시             위미중학교  33.280517  126.663575
# 3418  서귀포시             중문중학교  33.250278  126.428874
# 3419  서귀포시             표선중학교  33.330733  126.831046
# 3420  서귀포시             효돈중학교  33.264916  126.620738
# 3421  서귀포시             남주중학교  33.275937  126.564457
# 3422  서귀포시          서귀포여자중학교  33.200000  126.500000
# 3423  서귀포시            서귀포중학교  33.247751  126.569908
# 3424   제주시          제주동여자중학교  33.502542  126.540463
# 3425   제주시            제주동중학교  33.518813  126.571563
# 3426   제주시            제주서중학교  33.494526  126.480900
# 3427   제주시             아라중학교  33.500000  126.500000
# 3428   제주시           제주제일중학교  33.495201  126.538850
# 3429   제주시         제주중앙여자중학교  33.505250  126.521113
# 3430   제주시           제주중앙중학교  33.486617  126.500528
# 3431   제주시           신성여자중학교  33.477823  126.562738
# 3432   제주시             오현중학교  33.516542  126.556825
# 3433   제주시           제주여자중학교  33.482060  126.540963
# 3434   제주시             제주중학교  33.511937  126.516374
# 3435   제주시             한라중학교  33.477788  126.485117
# 3436   제주시             노형중학교  33.400000  126.400000
# 3437   제주시             오름중학교  33.516620  126.584599
# 3438   제주시             탐라중학교  33.491686  126.545093
# 3439   제주시            제주영지학교  33.488117  126.542748
# 3440   제주시            제주영송학교  33.450047  126.434217
# 3441  서귀포시           서귀포온성학교  33.291338  126.593310
# 3442   제주시  제주제일중학교부설방송통신중학교  33.495201  126.538850
#
# [3443 rows x 12 columns]

# %%
seoul_school = total_school_df[total_school_df['시도'] == '서울']
good_school = seoul_school[seoul_school['총합'] > 0]
seoul_map = folium.Map(location=[37.5614378, 126.9751701], zoom_start=11)

for n in good_school.index:
    folium.Marker([good_school['위도'][n], good_school['경도'][n]], popup=good_school['학교명_x'][n]).add_to(seoul_map)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# seoul_school['비율']
# seoul_school['총합'] / seoul_school['졸업자'] * 100
seoul_school['비율'] = seoul_school['총합'] / seoul_school['졸업자'] * 100
good_school = seoul_school[seoul_school['비율'] >= 3]
bad_school = seoul_school[seoul_school['비율'] < 3]
seoul_map = folium.Map(location=[37.5614378, 126.9751701], zoom_start=11)
for n in good_school.index:
    folium.CircleMarker([good_school['위도'][n], good_school['경도'][n]], color='crimson', fill_color='crimson', radius=7).add_to(seoul_map)

for n in bad_school.index:
    folium.CircleMarker([bad_schoool['위도'][n], bad_schoool['경도'][n]], color='#3186cc', fill_color='#3186cc', radius=7).add_to(seoul_map)

# %%
seoul_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
